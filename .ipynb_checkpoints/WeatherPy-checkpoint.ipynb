# %% [markdown]
# # Data Analysis
#
# There does not seem to be a trend when we compare Latitude to Humidity, Cloudiness, or Wind Speed. These weather traits seem to be independent of Latitude. However, we do see a trend in Latitiude vs. Maximum Temperature. Rather than being closer to the equator (0 degrees latitude), the closer the location is to 20 degrees Latitude, the higher the Max Temperature seems to be.

# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
cities = []

while len(cities) < 500:
    # Create a set of random lat and lng combinations
    lat_lngs = []
    cities = []
    lats = np.random.uniform(low=-90.000, high=90.000, size=1500) #change back to 1500 later
    lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
    lat_lngs = zip(lats, lngs)

    # Identify nearest city for each lat, lng combination
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

        # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
    "units": "metric",
    "appid": api_key
}

weather_df = pd.DataFrame(cities)
weather_df = weather_df.rename(columns={0:"Cities"})
weather_df["Cloudiness"] = ""
weather_df["Country"] = ""
weather_df["Date"] = ""
weather_df["Humidity"] = ""
weather_df["Lat"] = ""
weather_df["Lng"] = ""
weather_df["Max Temp"] = ""
weather_df["Wind Speed"] = ""

print("Beginning Data Retrieval")
print("-------------------------------------")

for index, row in weather_df.iterrows():
#     city_name = row["Cities"]
    params["q"] = row["Cities"]
    response = requests.get(url, params=params).json()
    
    try:
        
        weather_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        weather_df.loc[index, "Country"] = response["sys"]["country"]
        weather_df.loc[index, "Date"] = response["dt"]
        weather_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        weather_df.loc[index, "Lng"] = response["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
#         pprint(response)
        print(f"Processing Record for {index}: {row['Cities']}")
    except: #never found the error name so generalized
        print("No city found... skipping.")
        weather_df.loc[index, "Cloudiness"] = "N/A"
        weather_df.loc[index, "Country"] = "N/A"
        weather_df.loc[index, "Date"] = "N/A"
        weather_df.loc[index, "Humidity"] = "N/A"
        weather_df.loc[index, "Lat"] = "N/A"
        weather_df.loc[index, "Lng"] = "N/A"
        weather_df.loc[index, "Max Temp"] = "N/A"
        weather_df.loc[index, "Wind Speed"] = "N/A"

print("-------------------------------------")
print("Data Retrieval Complete")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record for 0: east london
# Processing Record for 1: sisimiut
# Processing Record for 2: bairnsdale
# Processing Record for 3: mataura
# Processing Record for 4: vaini
# Processing Record for 5: avarua
# Processing Record for 6: saskylakh
# Processing Record for 7: qasigiannguit
# Processing Record for 8: cape town
# Processing Record for 9: birao
# Processing Record for 10: lahat
# Processing Record for 11: ushuaia
# No city found... skipping.
# Processing Record for 13: san lazaro
# Processing Record for 14: demba
# Processing Record for 15: kapaa
# Processing Record for 16: qaanaaq
# Processing Record for 17: jamestown
# Processing Record for 18: vieux-habitants
# No city found... skipping.
# Processing Record for 20: iqaluit
# No city found... skipping.
# Processing Record for 22: yar-sale
# Processing Record for 23: vila velha
# Processing Record for 24: ambon
# Processing Record for 25: albany
# No city found... skipping.
# Processing Record for 27: new norfolk
# Processing Record for 28: asosa
# Processing Record for 29: barrow
# Processing Record for 30: san andres
# Processing Record for 31: phibun mangsahan
# Processing Record for 32: hithadhoo
# Processing Record for 33: rikitea
# Processing Record for 34: atuona
# Processing Record for 35: cabo san lucas
# Processing Record for 36: kerema
# Processing Record for 37: kutum
# Processing Record for 38: kushima
# Processing Record for 39: deputatskiy
# Processing Record for 40: lulea
# No city found... skipping.
# Processing Record for 42: tuktoyaktuk
# No city found... skipping.
# Processing Record for 44: mahabad
# Processing Record for 45: yamada
# Processing Record for 46: ambilobe
# Processing Record for 47: bluff
# Processing Record for 48: hobart
# Processing Record for 49: upernavik
# Processing Record for 50: port elizabeth
# Processing Record for 51: arraial do cabo
# Processing Record for 52: puerto ayora
# Processing Record for 53: altay
# Processing Record for 54: algiers
# Processing Record for 55: altamira
# Processing Record for 56: busselton
# Processing Record for 57: tazovskiy
# Processing Record for 58: butaritari
# Processing Record for 59: kununurra
# Processing Record for 60: geraldton
# Processing Record for 61: rocha
# Processing Record for 62: waipawa
# Processing Record for 63: hermiston
# Processing Record for 64: esperance
# No city found... skipping.
# Processing Record for 66: san cristobal
# Processing Record for 67: bredasdorp
# Processing Record for 68: aklavik
# Processing Record for 69: chokurdakh
# Processing Record for 70: saint george
# Processing Record for 71: oriximina
# Processing Record for 72: puquio
# Processing Record for 73: carnarvon
# Processing Record for 74: omsukchan
# Processing Record for 75: ribeira grande
# Processing Record for 76: severo-kurilsk
# Processing Record for 77: sao miguel do araguaia
# Processing Record for 78: toora-khem
# Processing Record for 79: nieuw nickerie
# Processing Record for 80: norman wells
# Processing Record for 81: souillac
# Processing Record for 82: mahebourg
# Processing Record for 83: sitka
# Processing Record for 84: fortuna foothills
# Processing Record for 85: khatanga
# No city found... skipping.
# No city found... skipping.
# Processing Record for 88: saldanha
# Processing Record for 89: buchanan
# Processing Record for 90: punta arenas
# Processing Record for 91: mount gambier
# Processing Record for 92: san patricio
# Processing Record for 93: yellowknife
# Processing Record for 94: hermanus
# Processing Record for 95: bathsheba
# Processing Record for 96: dezhou
# No city found... skipping.
# Processing Record for 98: kavaratti
# Processing Record for 99: viedma
# Processing Record for 100: castro
# Processing Record for 101: meulaboh
# Processing Record for 102: seoul
# Processing Record for 103: ixtapa
# No city found... skipping.
# Processing Record for 105: barcelos
# Processing Record for 106: pangnirtung
# No city found... skipping.
# Processing Record for 108: kahului
# Processing Record for 109: hilo
# Processing Record for 110: nikolskoye
# Processing Record for 111: la ronge
# No city found... skipping.
# Processing Record for 113: dingle
# Processing Record for 114: harper
# Processing Record for 115: lavrentiya
# No city found... skipping.
# Processing Record for 117: lompoc
# Processing Record for 118: clyde river
# Processing Record for 119: yatou
# No city found... skipping.
# Processing Record for 121: pahrump
# Processing Record for 122: bilma
# Processing Record for 123: georgetown
# Processing Record for 124: luderitz
# No city found... skipping.
# Processing Record for 126: bethel
# Processing Record for 127: port alfred
# No city found... skipping.
# Processing Record for 129: marsaxlokk
# Processing Record for 130: ilulissat
# Processing Record for 131: avera
# Processing Record for 132: mount isa
# Processing Record for 133: katsuura
# Processing Record for 134: ukiah
# Processing Record for 135: kaitangata
# Processing Record for 136: coihaique
# Processing Record for 137: mountain home
# Processing Record for 138: diego de almagro
# Processing Record for 139: saint-philippe
# Processing Record for 140: kulhudhuffushi
# Processing Record for 141: abha
# Processing Record for 142: nouakchott
# Processing Record for 143: ipswich
# Processing Record for 144: grindavik
# Processing Record for 145: roma
# Processing Record for 146: lebu
# Processing Record for 147: nuuk
# Processing Record for 148: bereznik
# Processing Record for 149: hambantota
# Processing Record for 150: solnechnyy
# No city found... skipping.
# Processing Record for 152: kangaatsiaq
# Processing Record for 153: ulagan
# Processing Record for 154: ulaanbaatar
# Processing Record for 155: mizan teferi
# Processing Record for 156: riyadh
# No city found... skipping.
# Processing Record for 158: ponta delgada
# Processing Record for 159: kamyshlov
# Processing Record for 160: bonavista
# Processing Record for 161: saint anthony
# No city found... skipping.
# Processing Record for 163: bandundu
# Processing Record for 164: keelung
# Processing Record for 165: honiara
# Processing Record for 166: victoria
# Processing Record for 167: salekhard
# Processing Record for 168: port blair
# Processing Record for 169: carutapera
# Processing Record for 170: novoagansk
# Processing Record for 171: nelson bay
# Processing Record for 172: tuatapere
# No city found... skipping.
# No city found... skipping.
# Processing Record for 175: hasaki
# Processing Record for 176: olinda
# Processing Record for 177: kamakhyanagar
# Processing Record for 178: eldorado
# No city found... skipping.
# Processing Record for 180: marsh harbour
# Processing Record for 181: chuy
# Processing Record for 182: wenatchee
# Processing Record for 183: tyukhtet
# Processing Record for 184: sawakin
# Processing Record for 185: acari
# Processing Record for 186: abu samrah
# Processing Record for 187: male
# Processing Record for 188: naberera
# Processing Record for 189: kodar
# Processing Record for 190: odate
# Processing Record for 191: fairmont
# Processing Record for 192: xilagani
# Processing Record for 193: ponta do sol
# Processing Record for 194: mayumba
# Processing Record for 195: luena
# Processing Record for 196: otavi
# Processing Record for 197: klaksvik
# Processing Record for 198: manzhouli
# Processing Record for 199: pevek
# Processing Record for 200: tasiilaq
# Processing Record for 201: tiksi
# Processing Record for 202: uglegorsk
# No city found... skipping.
# Processing Record for 204: ancud
# Processing Record for 205: najran
# Processing Record for 206: les cayes
# Processing Record for 207: ngaoundere
# No city found... skipping.
# Processing Record for 209: talcahuano
# Processing Record for 210: half moon bay
# Processing Record for 211: mar del plata
# No city found... skipping.
# Processing Record for 213: acapulco
# No city found... skipping.
# Processing Record for 215: toledo
# Processing Record for 216: constitucion
# Processing Record for 217: karachi
# Processing Record for 218: kavieng
# Processing Record for 219: jacmel
# Processing Record for 220: leningradskiy
# Processing Record for 221: dryden
# Processing Record for 222: hay river
# Processing Record for 223: pascagoula
# Processing Record for 224: hami
# Processing Record for 225: touros
# Processing Record for 226: altamura
# Processing Record for 227: guiratinga
# Processing Record for 228: cherskiy
# Processing Record for 229: san quintin
# Processing Record for 230: terenos
# Processing Record for 231: praya
# Processing Record for 232: praia
# Processing Record for 233: lumberton
# Processing Record for 234: beringovskiy
# Processing Record for 235: fortuna
# Processing Record for 236: challapata
# Processing Record for 237: longyearbyen
# Processing Record for 238: cloquet
# Processing Record for 239: gao
# Processing Record for 240: lagoa
# Processing Record for 241: coruripe
# Processing Record for 242: sao jose da coroa grande
# Processing Record for 243: maniitsoq
# Processing Record for 244: adrar
# Processing Record for 245: inirida
# Processing Record for 246: plettenberg bay
# Processing Record for 247: barentu
# Processing Record for 248: la asuncion
# No city found... skipping.
# Processing Record for 250: sorland
# Processing Record for 251: tulum
# Processing Record for 252: artesia
# Processing Record for 253: hatillo
# Processing Record for 254: key west
# Processing Record for 255: rabo de peixe
# No city found... skipping.
# Processing Record for 257: ostrovnoy
# Processing Record for 258: astana
# Processing Record for 259: coquimbo
# Processing Record for 260: guerrero negro
# Processing Record for 261: mazyr
# Processing Record for 262: abengourou
# Processing Record for 263: ngunguru
# Processing Record for 264: talnakh
# Processing Record for 265: santo tomas
# Processing Record for 266: naryan-mar
# Processing Record for 267: gawler
# Processing Record for 268: kodiak
# Processing Record for 269: sobolevo
# Processing Record for 270: saint-paul
# Processing Record for 271: aitape
# No city found... skipping.
# Processing Record for 273: kloulklubed
# Processing Record for 274: shimoda
# Processing Record for 275: kudahuvadhoo
# Processing Record for 276: jiwani
# Processing Record for 277: nizhnevartovsk
# Processing Record for 278: marsabit
# Processing Record for 279: neuquen
# Processing Record for 280: sao felix do xingu
# Processing Record for 281: tres arroyos
# Processing Record for 282: coffs harbour
# Processing Record for 283: olbia
# Processing Record for 284: timra
# Processing Record for 285: riohacha
# Processing Record for 286: torbay
# Processing Record for 287: kokopo
# Processing Record for 288: uyskoye
# Processing Record for 289: katherine
# No city found... skipping.
# Processing Record for 291: atambua
# Processing Record for 292: tahoua
# Processing Record for 293: flagstaff
# Processing Record for 294: cedar city
# Processing Record for 295: los llanos de aridane
# Processing Record for 296: saint-junien
# No city found... skipping.
# Processing Record for 298: kalanguy
# Processing Record for 299: manadhoo
# No city found... skipping.
# Processing Record for 301: kasangulu
# Processing Record for 302: veere
# Processing Record for 303: mehamn
# Processing Record for 304: provideniya
# Processing Record for 305: sao joao da barra
# Processing Record for 306: hervey bay
# Processing Record for 307: dwarka
# Processing Record for 308: emerald
# Processing Record for 309: moose factory
# Processing Record for 310: xai-xai
# Processing Record for 311: ketchikan
# Processing Record for 312: suntar
# No city found... skipping.
# Processing Record for 314: san vicente
# Processing Record for 315: san joaquin
# Processing Record for 316: yerbogachen
# Processing Record for 317: huallanca
# Processing Record for 318: banjar
# Processing Record for 319: kaspiyskiy
# Processing Record for 320: galesong
# Processing Record for 321: labuhan
# Processing Record for 322: shagonar
# Processing Record for 323: karacabey
# Processing Record for 324: morant bay
# Processing Record for 325: berlevag
# Processing Record for 326: jalingo
# Processing Record for 327: durres
# Processing Record for 328: mantua
# No city found... skipping.
# Processing Record for 330: tepoztlan
# No city found... skipping.
# Processing Record for 332: ankazoabo
# Processing Record for 333: bowen
# Processing Record for 334: gucheng
# Processing Record for 335: dongsheng
# Processing Record for 336: fenoarivo
# Processing Record for 337: dikson
# Processing Record for 338: hvide sande
# Processing Record for 339: vardo
# Processing Record for 340: beloha
# Processing Record for 341: pangody
# Processing Record for 342: key largo
# Processing Record for 343: bambous virieux
# Processing Record for 344: sorong
# Processing Record for 345: maragheh
# No city found... skipping.
# Processing Record for 347: karasjok
# Processing Record for 348: cabo rojo
# Processing Record for 349: miri
# Processing Record for 350: northfield
# No city found... skipping.
# Processing Record for 352: te anau
# Processing Record for 353: comodoro rivadavia
# Processing Record for 354: cidreira
# Processing Record for 355: tolga
# Processing Record for 356: wewak
# No city found... skipping.
# Processing Record for 358: loiza
# Processing Record for 359: tabou
# Processing Record for 360: bilibino
# Processing Record for 361: westport
# Processing Record for 362: waddan
# Processing Record for 363: aswan
# No city found... skipping.
# Processing Record for 365: zhuhai
# Processing Record for 366: salo
# Processing Record for 367: broome
# Processing Record for 368: port keats
# Processing Record for 369: buckeye
# Processing Record for 370: moree
# Processing Record for 371: ocos
# Processing Record for 372: weatherford
# No city found... skipping.
# Processing Record for 374: ciudad bolivar
# Processing Record for 375: itarema
# Processing Record for 376: leh
# Processing Record for 377: lundazi
# Processing Record for 378: komsomolskiy
# Processing Record for 379: lafia
# No city found... skipping.
# No city found... skipping.
# Processing Record for 382: thompson
# Processing Record for 383: ardakan
# Processing Record for 384: palmer
# Processing Record for 385: bad mergentheim
# Processing Record for 386: buraydah
# Processing Record for 387: tefe
# Processing Record for 388: medicine hat
# Processing Record for 389: celestun
# Processing Record for 390: mabaruma
# Processing Record for 391: vao
# Processing Record for 392: husavik
# Processing Record for 393: selma
# Processing Record for 394: pallisa
# Processing Record for 395: portland
# Processing Record for 396: dustlik
# No city found... skipping.
# Processing Record for 398: qatana
# Processing Record for 399: ende
# Processing Record for 400: mount vernon
# Processing Record for 401: povenets
# No city found... skipping.
# Processing Record for 403: black river
# Processing Record for 404: martapura
# Processing Record for 405: mufulira
# Processing Record for 406: jalu
# Processing Record for 407: vostok
# Processing Record for 408: singaraja
# Processing Record for 409: zabol
# Processing Record for 410: ballina
# Processing Record for 411: vanimo
# Processing Record for 412: minjur
# Processing Record for 413: alvand
# Processing Record for 414: sokur
# Processing Record for 415: rio gallegos
# No city found... skipping.
# Processing Record for 417: hibbing
# Processing Record for 418: altamont
# Processing Record for 419: norton
# Processing Record for 420: tura
# Processing Record for 421: beyneu
# Processing Record for 422: zilupe
# Processing Record for 423: hamilton
# Processing Record for 424: lakselv
# Processing Record for 425: port lincoln
# Processing Record for 426: apache junction
# Processing Record for 427: alofi
# Processing Record for 428: homer
# Processing Record for 429: biharamulo
# No city found... skipping.
# Processing Record for 431: porto novo
# Processing Record for 432: port moresby
# Processing Record for 433: cururupu
# Processing Record for 434: kruisfontein
# Processing Record for 435: jacareacanga
# Processing Record for 436: fayaoue
# Processing Record for 437: saint-francois
# Processing Record for 438: whitianga
# Processing Record for 439: acajutla
# Processing Record for 440: college
# No city found... skipping.
# Processing Record for 442: nanyang
# Processing Record for 443: new albany
# Processing Record for 444: fuerte olimpo
# Processing Record for 445: chase
# Processing Record for 446: santa cruz
# Processing Record for 447: iquique
# Processing Record for 448: nanortalik
# No city found... skipping.
# Processing Record for 450: baruun-urt
# Processing Record for 451: faanui
# Processing Record for 452: kawhia
# Processing Record for 453: trairi
# No city found... skipping.
# Processing Record for 455: richards bay
# Processing Record for 456: vila franca do campo
# Processing Record for 457: longyan
# Processing Record for 458: narsaq
# Processing Record for 459: porto murtinho
# Processing Record for 460: moron
# Processing Record for 461: amapa
# Processing Record for 462: suzun
# Processing Record for 463: berdigestyakh
# Processing Record for 464: coari
# No city found... skipping.
# No city found... skipping.
# Processing Record for 467: misratah
# Processing Record for 468: carolina
# Processing Record for 469: terra nova
# Processing Record for 470: nome
# Processing Record for 471: batagay
# Processing Record for 472: glenluce
# Processing Record for 473: lardos
# Processing Record for 474: gardez
# Processing Record for 475: kysyl-syr
# Processing Record for 476: nalut
# Processing Record for 477: ola
# Processing Record for 478: bulgan
# No city found... skipping.
# Processing Record for 480: rossland
# Processing Record for 481: praia da vitoria
# Processing Record for 482: puerto leguizamo
# Processing Record for 483: douentza
# Processing Record for 484: puerto escondido
# Processing Record for 485: itacoatiara
# Processing Record for 486: latung
# Processing Record for 487: carndonagh
# Processing Record for 488: paamiut
# Processing Record for 489: cockburn town
# Processing Record for 490: kochevo
# Processing Record for 491: torzhok
# Processing Record for 492: batagay-alyta
# Processing Record for 493: san mateo del mar
# Processing Record for 494: irbeyskoye
# Processing Record for 495: lyndon
# Processing Record for 496: rosetta
# Processing Record for 497: mae sot
# Processing Record for 498: quchan
# Processing Record for 499: kalangala
# Processing Record for 500: jan kempdorp
# No city found... skipping.
# No city found... skipping.
# Processing Record for 503: kilindoni
# Processing Record for 504: dandong
# Processing Record for 505: solomenskoye
# Processing Record for 506: port hawkesbury
# Processing Record for 507: saint-augustin
# Processing Record for 508: sahaswan
# Processing Record for 509: dzilam gonzalez
# Processing Record for 510: margherita
# Processing Record for 511: bahia blanca
# Processing Record for 512: kintampo
# No city found... skipping.
# Processing Record for 514: la tuque
# Processing Record for 515: muhos
# Processing Record for 516: mauguio
# Processing Record for 517: siilinjarvi
# Processing Record for 518: anadyr
# Processing Record for 519: narasapur
# Processing Record for 520: henties bay
# Processing Record for 521: virginia beach
# Processing Record for 522: zhigansk
# Processing Record for 523: malinalco
# Processing Record for 524: matagami
# Processing Record for 525: xiongzhou
# Processing Record for 526: muli
# Processing Record for 527: limbang
# Processing Record for 528: havoysund
# Processing Record for 529: padang
# Processing Record for 530: zhanakorgan
# Processing Record for 531: lensk
# Processing Record for 532: methala
# Processing Record for 533: oeiras do para
# Processing Record for 534: wellington
# Processing Record for 535: flinders
# Processing Record for 536: sendhwa
# No city found... skipping.
# Processing Record for 538: dali
# Processing Record for 539: aksarka
# Processing Record for 540: vaitape
# No city found... skipping.
# Processing Record for 542: the valley
# Processing Record for 543: pochutla
# Processing Record for 544: kurunegala
# Processing Record for 545: pervomayskiy
# Processing Record for 546: namatanai
# Processing Record for 547: cayeli
# Processing Record for 548: kushuhum
# Processing Record for 549: zyryanka
# Processing Record for 550: ahuimanu
# Processing Record for 551: sabang
# Processing Record for 552: oussouye
# No city found... skipping.
# No city found... skipping.
# Processing Record for 555: faya
# No city found... skipping.
# Processing Record for 557: lai
# No city found... skipping.
# Processing Record for 559: sinnamary
# Processing Record for 560: puerto madero
# Processing Record for 561: cooma
# Processing Record for 562: rudnya
# Processing Record for 563: le pont-de-claix
# No city found... skipping.
# No city found... skipping.
# Processing Record for 566: spasskoye
# Processing Record for 567: severo-yeniseyskiy
# Processing Record for 568: baykit
# No city found... skipping.
# Processing Record for 570: moerai
# Processing Record for 571: barranca
# Processing Record for 572: krasnovishersk
# Processing Record for 573: khomutovo
# Processing Record for 574: isangel
# Processing Record for 575: sharjah
# Processing Record for 576: krasnokholm
# Processing Record for 577: lata
# Processing Record for 578: hailar
# Processing Record for 579: kieta
# Processing Record for 580: lewistown
# Processing Record for 581: yulara
# Processing Record for 582: sokoni
# Processing Record for 583: havre
# Processing Record for 584: basco
# Processing Record for 585: belyy yar
# Processing Record for 586: mugur-aksy
# No city found... skipping.
# Processing Record for 588: muros
# Processing Record for 589: almere
# Processing Record for 590: chapais
# No city found... skipping.
# Processing Record for 592: anapskaya
# Processing Record for 593: tual
# Processing Record for 594: naze
# Processing Record for 595: pontes e lacerda
# Processing Record for 596: teguldet
# Processing Record for 597: sanming
# Processing Record for 598: basirpur
# Processing Record for 599: palmas bellas
# Processing Record for 600: zhigalovo
# Processing Record for 601: zalantun
# Processing Record for 602: samus
# No city found... skipping.
# Processing Record for 604: monteagudo
# Processing Record for 605: paita
# Processing Record for 606: dunedin
# No city found... skipping.
# -------------------------------------
# Data Retrieval Complete

# %%
weather_df
# Out:
#                Cities Cloudiness Country        Date Humidity    Lat     Lng  \
# 0         east london          6      ZA  1561338578       85 -33.02   27.91
# 1            sisimiut         98      GL  1561338578       95  66.94  -53.67
# 2          bairnsdale          0      AU  1561338578       84 -37.83  147.63
# 3             mataura         93      NZ  1561338579       88 -46.19  168.86
# 4               vaini         75      IN  1561338579      100  15.34   74.49
# 5              avarua         63      CK  1561338425       53 -21.21 -159.78
# 6           saskylakh        100      RU  1561338580       48  71.97  114.09
# 7       qasigiannguit         75      GL  1561338580       52  68.82  -51.19
# 8           cape town         99      ZA  1561338580      100 -33.93   18.42
# 9               birao         91      CF  1561338580       67   10.3   22.78
# 10              lahat         99      ID  1561338581       87  -3.78  103.55
# 11            ushuaia         75      AR  1561338480       98 -54.81  -68.31
# 12          taolanaro        N/A     N/A         N/A      N/A    N/A     N/A
# 13         san lazaro         20      BZ  1561338581       83  18.04  -88.66
# 14              demba          0      CD  1561338582       47  -5.47   22.27
# 15              kapaa         90      US  1561338582       94  22.08 -159.32
# 16            qaanaaq        100      GL  1561338582       71  77.48  -69.36
# 17          jamestown         33      AU  1561338583       55 -33.21   138.6
# 18    vieux-habitants          0      GP  1561338583       83  16.06  -61.77
# 19            da nang        N/A     N/A         N/A      N/A    N/A     N/A
# 20            iqaluit         75      CA  1561338583       62  63.75  -68.52
# 21   illoqqortoormiut        N/A     N/A         N/A      N/A    N/A     N/A
# 22           yar-sale         99      RU  1561338584       77  66.83   70.83
# 23         vila velha         20      BR  1561338293       78  -3.71   -38.6
# 24              ambon        100      FR  1561338584      100  47.55   -2.56
# 25             albany         40      US  1561338466       40  42.65  -73.75
# 26           olafsvik        N/A     N/A         N/A      N/A    N/A     N/A
# 27        new norfolk         20      AU  1561338585       80 -42.78  147.06
# 28              asosa         98      ET  1561338585       94  10.07   34.53
# 594              naze        100      NG  1561338767       97   5.43    7.07
# 595  pontes e lacerda          0      BR  1561338767       51 -15.23  -59.33
# 596          teguldet        100      RU  1561338767       98  57.31   88.17
# 597           sanming        100      CN  1561338767       99  26.24   117.6
# 598          basirpur         65      PK  1561338768       36  30.58   73.84
# 599     palmas bellas         40      PA  1561338768       83   9.23  -80.09
# 600         zhigalovo          8      RU  1561338768       46  54.81  105.15
# 601          zalantun         92      CN  1561338769       59     48  122.72
# 602             samus         40      RU  1561338769       87  56.74    84.7
# 603         skalistyy        N/A     N/A         N/A      N/A    N/A     N/A
# 604        monteagudo          0      BO  1561338769       69  -19.8  -63.96
# 605             paita         55      PE  1561338770       90  -5.09  -81.11
# 606           dunedin        100      NZ  1561338476       62 -45.87   170.5
# 607          temaraia        N/A     N/A         N/A      N/A    N/A     N/A
#
#     Max Temp Wind Speed
# 0      10.06       2.04
# 1       3.29       0.94
# 2       9.44       0.45
# 3         10       3.58
# 4         22       1.25
# 5         24        8.2
# 6       18.9       4.46
# 7          8        3.1
# 8      12.22        3.6
# 9      24.58       2.05
# 10     20.54       1.09
# 11         4        2.1
# 12       N/A        N/A
# 13        30        5.1
# 14      19.3       0.55
# 15        27        3.6
# 16       1.3       1.12
# 17      7.04       2.84
# 18        27        2.6
# 19       N/A        N/A
# 20        11        6.7
# 21       N/A        N/A
# 22      12.2       5.88
# 23        30        3.1
# 24     17.22          1
# 25     23.89        6.7
# 26       N/A        N/A
# 27      6.67        5.1
# 28     18.66        0.8
# 29     10.15        2.3
# ..       ...        ...
# 578    23.17       2.74
# 579    27.92       1.48
# 580    24.44        1.5
# 581       10        4.6
# 582    10.45       1.96
# 583       21        9.3
# 584    23.89        1.5
# 585       15          3
# 586      5.4       3.15
# 587      N/A        N/A
# 588    17.78          1
# 589    22.78        5.1
# 590       19        4.6
# 591      N/A        N/A
# 592       19          3
# 593    26.56      10.32
# 594    23.23       1.58
# 595    22.81       1.76
# 596    12.88       4.24
# 597    19.67       1.58
# 598    33.38       4.93
# 599    28.33        2.6
# 600     19.5       1.31
# 601    24.09       1.02
# 602    13.33          4
# 603      N/A        N/A
# 604    14.31       1.28
# 605    18.31       7.31
# 606    11.67       9.83
# 607      N/A        N/A
#
# [608 rows x 9 columns]

# %%
weather_df2 = weather_df.loc[weather_df["Cloudiness"] != "N/A",:]
weather_df2
# Out:
#                Cities Cloudiness Country        Date Humidity    Lat     Lng  \
# 0         east london          6      ZA  1561338578       85 -33.02   27.91
# 1            sisimiut         98      GL  1561338578       95  66.94  -53.67
# 2          bairnsdale          0      AU  1561338578       84 -37.83  147.63
# 3             mataura         93      NZ  1561338579       88 -46.19  168.86
# 4               vaini         75      IN  1561338579      100  15.34   74.49
# 5              avarua         63      CK  1561338425       53 -21.21 -159.78
# 6           saskylakh        100      RU  1561338580       48  71.97  114.09
# 7       qasigiannguit         75      GL  1561338580       52  68.82  -51.19
# 8           cape town         99      ZA  1561338580      100 -33.93   18.42
# 9               birao         91      CF  1561338580       67   10.3   22.78
# 10              lahat         99      ID  1561338581       87  -3.78  103.55
# 8      12.22        3.6
# 9      24.58       2.05
# 10     20.54       1.09
# 11         4        2.1
# 13        30        5.1
# 14      19.3       0.55
# 15        27        3.6
# 16       1.3       1.12
# 17      7.04       2.84
# 18        27        2.6
# 20        11        6.7
# 22      12.2       5.88
# 23        30        3.1
# 24     17.22          1
# 25     23.89        6.7
# 27      6.67        5.1
# 28     18.66        0.8
# 29     10.15        2.3
# 30     28.25       0.56
# 31        29        1.5
# 32     28.82       3.86
# 33     19.28       3.26
# ..       ...        ...
# 574       24        4.1
# 575       35          1
# 576    20.56       0.93
# 577     3.26       0.79
# 578    23.17       2.74
# 579    27.92       1.48
# 580    24.44        1.5
# 581       10        4.6
# 582    10.45       1.96
# 583       21        9.3
# 584    23.89        1.5
# 585       15          3
# 586      5.4       3.15
# 588    17.78          1
# 589    22.78        5.1
# 590       19        4.6
# 592       19          3
# 593    26.56      10.32
# 594    23.23       1.58
# 595    22.81       1.76
# 596    12.88       4.24
# 597    19.67       1.58
# 598    33.38       4.93
# 599    28.33        2.6
# 600     19.5       1.31
# 601    24.09       1.02
# 602    13.33          4
# 604    14.31       1.28
# 605    18.31       7.31
# 606    11.67       9.83
#
# [539 rows x 9 columns]

# %%
cities_count = weather_df2.count()
cities_count
# Out:
# Cities        539
# Cloudiness    539
# Country       539
# Date          539
# Humidity      539
# Lat           539
# Lng           539
# Max Temp      539
# Wind Speed    539
# dtype: int64

# %%
timestamp = weather_df2.loc[0,"Date"]
dt_object = datetime.fromtimestamp(timestamp)
date = dt_object.strftime("%m/%d/%Y")
date
# Out:
# '06/23/2019'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()

fig.suptitle(f"City Latitude vs. Max Temperature ({date})", fontsize=14, fontweight="bold")
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")

# ax.set_xlim(-90,90)
ax.grid()

lat_temp = ax.scatter(weather_df2["Lat"], weather_df2["Max Temp"], marker="o", alpha = 0.75, edgecolors = "black")
plt.savefig("latvstemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()

fig.suptitle(f"City Latitude vs. Humidity ({date})", fontsize=14, fontweight="bold")
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")

ax.set_ylim(0,110)
ax.grid()

lat_temp = ax.scatter(weather_df2["Lat"], weather_df2["Humidity"], marker="o", alpha = 0.75, edgecolors = "black")
plt.savefig("latvshumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()

fig.suptitle(f"City Latitude vs. Cloudiness ({date})", fontsize=14, fontweight="bold")
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness(%)")

# ax.set_xlim(-90,90)
ax.grid()

lat_temp = ax.scatter(weather_df2["Lat"], weather_df2["Cloudiness"], marker="o", alpha = 0.75, edgecolors = "black")
plt.savefig("latvscloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()

fig.suptitle(f"City Latitude vs. Wind Speed ({date})", fontsize=14, fontweight="bold")
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (%)")

# ax.set_xlim(-90,90)
ax.grid()

lat_temp = ax.scatter(weather_df2["Lat"], weather_df2["Wind Speed"], marker="o",  alpha = 0.75, edgecolors = "black")
plt.savefig("latvswindspeed.png")
